# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd
import sympy as sp

i = np.linspace(-10,10,400)
x=sp.symbols('x')
y=-x
print("x(dot)=")
display(y)
v=sp.integrate(-y,x)


print('v(x)=')
display(v)
xdot=[]
V=[]
for X in i:
    xdot.append(y.evalf(subs={x:X}))
    V.append(v.evalf(subs={x:X}))
Table=pd.DataFrame()
print(type(xdot[0]))
Table['x']=i
Table['dx/dt']=np.array(xdot).astype(np.float64)
Table['v(x)']=np.array(V).astype(np.float64)
display(Table)
a=np.empty(len(Table))
a.fill(0)
fig=go.Figure()
fig.add_trace(go.Scatter(x=Table['x'],y=Table['dx/dt'],mode='lines',name=sp.latex(y)))
fig.add_trace(go.Scatter(x=Table['x'],y=Table['v(x)'],mode='lines',name='$'+sp.latex(v)+'$'))


fig.show()
# Out:
# x(dot)=
# -x
# v(x)=
# x**2/2
# <class 'sympy.core.numbers.Float'>
#              x      dx/dt       v(x)
# 0   -10.000000  10.000000  50.000000
# 1    -9.949875   9.949875  49.500003
# 2    -9.899749   9.899749  49.002519
# 3    -9.849624   9.849624  48.507547
# 4    -9.799499   9.799499  48.015088
# ..         ...        ...        ...
# 395   9.799499  -9.799499  48.015088
# 396   9.849624  -9.849624  48.507547
# 397   9.899749  -9.899749  49.002519
# 398   9.949875  -9.949875  49.500003
# 399  10.000000 -10.000000  50.000000
#
# [400 rows x 3 columns]
# ...

# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd
import sympy as sp

i = np.linspace(-2,2,400)
x=sp.symbols('x')
y=x-x**3
print("x(dot)=")
display(y)
v=sp.integrate(-y,x)


print('v(x)=')
display(v)
xdot=[]
V=[]
for X in i:
    xdot.append(y.evalf(subs={x:X}))
    V.append(v.evalf(subs={x:X}))
Table=pd.DataFrame()
print(type(xdot[0]))
Table['x']=i
Table['dx/dt']=np.array(xdot).astype(np.float64)
Table['v(x)']=np.array(V).astype(np.float64)
display(Table)
a=np.empty(len(Table))
a.fill(0)
fig=go.Figure()
fig.add_trace(go.Scatter(x=Table['x'],y=Table['dx/dt'],mode='lines',name=sp.latex(y)))
fig.add_trace(go.Scatter(x=Table['x'],y=Table['v(x)'],mode='lines',name='$'+sp.latex(v)+'$'))


fig.show()
# Out:
# x(dot)=
# -x**3 + x
# v(x)=
# x**4/4 - x**2/2
# <class 'sympy.core.numbers.Float'>
#             x     dx/dt      v(x)
# 0   -2.000000  6.000000  2.000000
# 1   -1.989975  5.890326  1.940400
# 2   -1.979950  5.781853  1.881894
# 3   -1.969925  5.674573  1.824470
# 4   -1.959900  5.568481  1.768114
# ..        ...       ...       ...
# 395  1.959900 -5.568481  1.768114
# 396  1.969925 -5.674573  1.824470
# 397  1.979950 -5.781853  1.881894
# 398  1.989975 -5.890326  1.940400
# 399  2.000000 -6.000000  2.000000
#
# [400 rows x 3 columns]
# ...

# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd
import sympy as sp

i = np.linspace(-2,2,400)
x=sp.symbols('x')
y=x*(1-x)
print("x(dot)=")
display(y)
v=sp.integrate(-y,x)


print('v(x)=')
display(v)
xdot=[]
V=[]
for X in i:
    xdot.append(y.evalf(subs={x:X}))
    V.append(v.evalf(subs={x:X}))
Table=pd.DataFrame()
print(type(xdot[0]))
Table['x']=i
Table['dx/dt']=np.array(xdot).astype(np.float64)
Table['v(x)']=np.array(V).astype(np.float64)
display(Table)
a=np.empty(len(Table))
a.fill(0)
fig=go.Figure()
fig.add_trace(go.Scatter(x=Table['x'],y=Table['dx/dt'],mode='lines',name=sp.latex(y)))
fig.add_trace(go.Scatter(x=Table['x'],y=Table['v(x)'],mode='lines',name='$'+sp.latex(v)+'$'))


fig.show()
# Out:
# x(dot)=
# x*(1 - x)
# v(x)=
# x**3/3 - x**2/2
# <class 'sympy.core.numbers.Float'>
#             x     dx/dt      v(x)
# 0   -2.000000 -6.000000 -4.666667
# 1   -1.989975 -5.949975 -4.606767
# 2   -1.979950 -5.900151 -4.547368
# 3   -1.969925 -5.850529 -4.488468
# 4   -1.959900 -5.801107 -4.430064
# ..        ...       ...       ...
# 395  1.959900 -1.881307  0.588857
# 396  1.969925 -1.910679  0.607864
# 397  1.979950 -1.940252  0.627167
# 398  1.989975 -1.970025  0.646767
# 399  2.000000 -2.000000  0.666667
#
# [400 rows x 3 columns]
# ...

# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd
import sympy as sp

i = np.linspace(-4*np.pi,4*np.pi,400)
x=sp.symbols('x')
y=sp.sin(x)
print("x(dot)=")
display(y)
v=sp.integrate(-y,x)


print('v(x)=')
display(v)
xdot=[]
V=[]
for X in i:
    xdot.append(y.evalf(subs={x:X}))
    V.append(v.evalf(subs={x:X}))
Table=pd.DataFrame()
print(type(xdot[0]))
Table['x']=i
Table['dx/dt']=np.array(xdot).astype(np.float64)
Table['v(x)']=np.array(V).astype(np.float64)
display(Table)
a=np.empty(len(Table))
a.fill(0)
fig=go.Figure()
fig.add_trace(go.Scatter(x=Table['x'],y=Table['dx/dt'],mode='lines',name=sp.latex(y)))
fig.add_trace(go.Scatter(x=Table['x'],y=Table['v(x)'],mode='lines',name='$'+sp.latex(v)+'$'))


fig.show()
# Out:
# x(dot)=
# sin(x)
# v(x)=
# cos(x)
# <class 'sympy.core.numbers.Float'>
#              x         dx/dt      v(x)
# 0   -12.566371  4.898587e-16  1.000000
# 1   -12.503381  6.294768e-02  0.998017
# 2   -12.440392  1.256457e-01  0.992075
# 3   -12.377403  1.878453e-01  0.982199
# 4   -12.314413  2.492999e-01  0.968426
# ..         ...           ...       ...
# 395  12.314413 -2.492999e-01  0.968426
# 396  12.377403 -1.878453e-01  0.982199
# 397  12.440392 -1.256457e-01  0.992075
# 398  12.503381 -6.294768e-02  0.998017
# 399  12.566371 -4.898587e-16  1.000000
#
# [400 rows x 3 columns]
# ...
